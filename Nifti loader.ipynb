# %%
import nibabel as nib
image = nib.load("C:\\Users\\win10\\kanama-ayirtedici-2-pytorch\\small\\t1\\IXI102-HH-1416-T1_fcm.nii.gz")
image_data = image.get_fdata()

# %%
import matplotlib.pyplot as plt

# %%
image_data.shape
# Out:
# (120, 120, 90)

# %%
from numpy import expand_dims
image_data = expand_dims(image_data, axis=3)
image_data.shape
# Out:
# (120, 120, 90, 1)

# %%
plt.matshow(image_data[40,:,:, 0], cmap=plt.cm.bone)

# %%
image = nib.load("C:\\Users\\win10\\kanama-ayirtedici-2-pytorch\\small\\t2\\IXI102-HH-1416-T2_reg_fcm.nii.gz")
image_data_t2 = image.get_fdata()

# %%
image_data_t2.shape
# Out:
# (120, 120, 90)

# %%
image_data_t2 = expand_dims(image_data_t2, axis=3)
image_data_t2.shape
# Out:
# (120, 120, 90, 1)

# %%
plt.matshow(image_data_t2[40,:,:, 0], cmap=plt.cm.bone)
